# %% [markdown]
# <a href="https://colab.research.google.com/github/HimanshuRajput-0/Kafka/blob/main/Kfka_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Kafka -Python :**

# %% [markdown]
# ```kafka-python is a pure-python client library for Apache Kafka, the distributed stream processing engine.```

# %% [markdown]
# ```It has no external dependencies and no Cython/C/rust core, making installation across a wide variety of environments simple and easy to manage.```

# %% [markdown]
# ``` It provides high-level class components for consumer, producer, and admin clients, as well as CLI scripts for quick interactive tasks.```

# %% [markdown]
# ```kafka-python admin serves as a simple alternative to the apache kafka bin/ scripts, particularly if/when you do not have easy access to an installed/compatible jvm. The CLI interface for admin commands is provided as kafka-python admin and python -m kafka.admin.```

# %% [markdown]
# ```Users looking to add more raw throughput can pip install crc32c as an optional dependency, offloading one of the most CPU intensive subsystems to an optimized C library.```

# %% [markdown]
# **Installation :**

# %% [markdown]
# ``` Download java and kafka.```

# %%
pip install kafka-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.9/613.9 kB 10.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ```Kafka Consumers :```

# %%
from kafka import KafkaConsumer

consumer = KafkaConsumer("Hello")

for msg in consumer:
  print(msg)
# Out:
# ERROR:kafka.net.manager:Connection failed: KafkaConnectionError: 111 ECONNREFUSED
# ERROR:kafka.net.connection:<KafkaConnection node_id=bootstrap-0 broker_version=unknown (disconnected)>: Connection lost: KafkaConnectionError: 111 ECONNREFUSED
# WARNING:kafka.net.manager:Bootstrap connection to bootstrap-0 failed: KafkaConnectionError: 111 ECONNREFUSED (backoff 0.10 secs)
# WARNING:kafka.net.manager:Bootstrap bootstrap-0 not ready; waiting 0.09 secs
# ERROR:kafka.net.manager:Connection failed: KafkaConnectionError: 111 ECONNREFUSED
# ERROR:kafka.net.connection:<KafkaConnection node_id=bootstrap-0 broker_version=unknown (disconnected)>: Connection lost: KafkaConnectionError: 111 ECONNREFUSED
# WARNING:kafka.net.manager:Bootstrap connection to bootstrap-0 failed: KafkaConnectionError: 111 ECONNREFUSED (backoff 0.47 secs)
# WARNING:kafka.net.manager:Bootstrap bootstrap-0 not ready; waiting 0.47 secs
# ERROR:kafka.net.manager:Connection failed: KafkaConnectionError: 111 ECONNREFUSED
# ...
